# %%
# Code to show how moviepy works

from moviepy.editor import *

# Create a video clip from an image
clip = ImageClip("image.jpg").set_duration(10)

# Add some text to the video clip
text = TextClip("Hello World", fontsize=50, color='white').set_pos('center').set_duration(10)

# Combine the image clip and the text clip
final_clip = CompositeVideoClip([clip, text])

# Write the final clip to a file
final_clip.write_videofile("video.mp4", fps=24)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/moviepy/video/VideoClip.py:1137, in TextClip.__init__(self, txt, filename, size, color, bg_color, fontsize, font, stroke_color, stroke_width, method, kerning, align, interline, tempfilename, temptxt, transparent, remove_temp, print_cmd)
#    1136 try:
# -> 1137     subprocess_call(cmd, logger=None)
#    1138 except (IOError, OSError) as err:
#
# File ~/anaconda3/lib/python3.9/site-packages/moviepy/tools.py:46, in subprocess_call(cmd, logger, errorprint)
#      44     popen_params["creationflags"] = 0x08000000
# ---> 46 proc = sp.Popen(cmd, **popen_params)
#      48 out, err = proc.communicate() # proc.wait()
#
# ...

# %%
# code for pyforest

import pyforest
from sklearn.datasets import load_iris
import seaborn as sns
import pandas as pd

data = load_iris()

df = pd.DataFrame(data.data, columns=data.feature_names)

df.head()

sns.scatterplot(x=df['sepal length (cm)'], y=df['sepal width (cm)'], hue=data.target)
# Out:
# <AxesSubplot:xlabel='sepal length (cm)', ylabel='sepal width (cm)'>

# %%
import cv2

# Initialize the camera
cap = cv2.VideoCapture(0)

# Loop until the user presses the 'q' key
while True:
    # Capture the current frame
    _, frame = cap.read()

    # Convert the current frame to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Display the grayscale frame
    cv2.imshow('frame', gray)

    # Check if the user pressed the 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and destroy all windows
cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@0.049] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@0.050] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /home/espersonnel/Development/lux-dev-data-science/week-2/other-py-libraries.ipynb Cell 3 in <cell line: 9>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/espersonnel/Development/lux-dev-data-science/week-2/other-py-libraries.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> _, frame = cap.read()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/espersonnel/Development/lux-dev-data-science/week-2/other-py-libraries.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> # Convert the current frame to grayscale
# ...

# %%
import cv2

# read in the image
img = cv2.imread('image.jpg')

# define the coordinates of the rectangle
x, y = 100, 50
w, h = 100, 100

# draw the rectangle on the image
cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

# display the resulting image
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x555fa04fe8f0) is not the object's thread (0x555fa1047020).
# Cannot move to target thread (0x555fa04fe8f0)
#
# QObject::moveToThread: Current thread (0x555fa04fe8f0) is not the object's thread (0x555fa1047020).
# Cannot move to target thread (0x555fa04fe8f0)
#
# QObject::moveToThread: Current thread (0x555fa04fe8f0) is not the object's thread (0x555fa1047020).
# Cannot move to target thread (0x555fa04fe8f0)
#
# QObject::moveToThread: Current thread (0x555fa04fe8f0) is not the object's thread (0x555fa1047020).
# Cannot move to target thread (0x555fa04fe8f0)
#
# QObject::moveToThread: Current thread (0x555fa04fe8f0) is not the object's thread (0x555fa1047020).
# Cannot move to target thread (0x555fa04fe8f0)
#
# QObject::moveToThread: Current thread (0x555fa04fe8f0) is not the object's thread (0x555fa1047020).
# Cannot move to target thread (0x555fa04fe8f0)
#
# ...

# %%
# OpenCV program to perform Edge detection in real time
# import libraries of python OpenCV
# where its functionality resides
import cv2

# np is an alias pointing to numpy library
import numpy as np

# capture frames from a camera
cap = cv2.VideoCapture(0)

# loop runs if capturing has been initialized
while(1):
    
        # reads frames from a camera
        _, frame = cap.read()
    
        # converting BGR to HSV
        hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    
        # define range of red color in HSV
        lower_red = np.array([30,150,50])
        upper_red = np.array([255,255,180])
    
        # create a red HSV colour boundary and
        # threshold HSV image
        mask = cv2.inRange(hsv, lower_red, upper_red)
    
        # Bitwise-AND mask and original image
        res = cv2.bitwise_and(frame,frame, mask= mask)
    
        # Display an original image
        cv2.imshow('Original',frame)
    
        # finds edges in the input image image and
        # marks them in the output map edges
        edges = cv2.Canny(frame,100,200)
    
        # Display edges in a frame
        cv2.imshow('Edges',edges)
    
        # Wait for Esc key to stop
        k = cv2.waitKey(5) & 0xFF
        if k == 27:
            break
    
# Close the window
cap.release()

# De-allocate any associated memory usage
cv2.destroyAllWindows()

# %%
# OpenCV code for face detection
import cv2

# Load the cascade classifier
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Read the input image
img = cv2.imread('profile.png')

# Convert the input into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.1, 4)

# Draw rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Display the output
cv2.imshow('img', img)
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# [ERROR:0@0.094] global persistence.cpp:505 open Can't open file: 'haarcascade_frontalface_default.xml' in read mode
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /home/espersonnel/Development/lux-dev-data-science/week-2/other-py-libraries.ipynb Cell 6 in <cell line: 14>()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/espersonnel/Development/lux-dev-data-science/week-2/other-py-libraries.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/home/espersonnel/Development/lux-dev-data-science/week-2/other-py-libraries.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> # Detect faces
# ...

# %%
# FastAPI code

from fastapi import FastAPI

app = FastAPI()

@app.get("/")
async def root():
    return {"message": "Hello World"}

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import joblib

app = FastAPI()

class MyData(BaseModel):
    sepal_length: float
    sepal_width: float
    petal_length: float
    petal_width: float

@app.post("/predict")
async def predict_species(data: MyData):
    model = joblib.load("my_model.pkl")
    X = [[data.sepal_length, data.sepal_width, data.petal_length, data.petal_width]]
    prediction = model.predict(X)
    return {"prediction": prediction[0]}

# %%
### Pairplot

# %%
import seaborn as sns

sns.set(style="ticks", color_codes=True)
g = sns.pairplot(df, hue="Survived")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/espersonnel/Development/lux-dev-data-science/week-2/other-py-libraries.ipynb Cell 10 in <cell line: 4>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/espersonnel/Development/lux-dev-data-science/week-2/other-py-libraries.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import seaborn as sns
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/espersonnel/Development/lux-dev-data-science/week-2/other-py-libraries.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> sns.set(style="ticks", color_codes=True)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/espersonnel/Development/lux-dev-data-science/week-2/other-py-libraries.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> g = sns.pairplot(df, hue="Survived")
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt

plt.hist([df[df['Pclass']==1]['Age'], df[df['Pclass']==2]['Age'], df[df['Pclass']==3]['Age']], stacked=True, color = ['g','r','b'],label = ['1st Class','2nd Class','3rd Class'])
plt.legend(loc='upper right')
plt.title('Age vs Class')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/espersonnel/Development/lux-dev-data-science/week-2/other-py-libraries.ipynb Cell 11 in <cell line: 3>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/espersonnel/Development/lux-dev-data-science/week-2/other-py-libraries.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/espersonnel/Development/lux-dev-data-science/week-2/other-py-libraries.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> plt.hist([df[df['Pclass']==1]['Age'], df[df['Pclass']==2]['Age'], df[df['Pclass']==3]['Age']], stacked=True, color = ['g','r','b'],label = ['1st Class','2nd Class','3rd Class'])
# ...
